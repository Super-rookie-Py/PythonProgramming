# %% [markdown]
# <a href="https://colab.research.google.com/github/Super-rookie-Py/PythonProgramming/blob/master/%EB%B0%95%EA%B1%B4%EC%9A%B0__06_%EC%9E%85%EB%A0%A5%EA%B3%BC_%EC%B6%9C%EB%A0%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 입력과 출력
# - keonwoo Park 2020/08/21

# %% [markdown]
# ---

# %% [markdown]
# ## 표준 입출력(Standard Input/Output)

# %% [markdown]
# ### 표준 입력 함수

# %%
name = input("이름: ")
print(name)
# Out:
# 이름: 박건우
# 박건우

# %% [markdown]
# #### [Lab] 섭씨 온도를 화씨 온도로 변환
#
# * 섭씨 온도를 화씨 온도로 변환하는 공식: $F = (C * 1.8) + 32$

# %%
celsius = float(input("섭씨 온도: "))
fahrenheit = (celsius * 1.8) + 32
print("화씨 온도는:", fahrenheit)
# Out:
# 섭씨 온도: 34
# 화씨 온도는: 93.2

# %% [markdown]
# #### [Lab] 구구단 중의 하나의 단을 입력받아 계산
#
# * 출력할 단을 입력
# * 해당 단의 계산 결과 출력

# %%
N = int(input("출력할 단: "))
for j in range(1,10):
  print("{0} X {1} = {2}".format(N,j,N*j))
# Out:
# 출력할 단: 7
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63

# %% [markdown]
# ### 표준 출력 함수

# %%
print("Hello Python")
print("안녕 파이썬")
print(7)
print(3.14)
print([1, 2, 3])

print("Hello","Python", sep = "---")
print(1, 2, 3)
print(1, end = ' ')
print(2, end = ' ')
print(3, end = ' ')
print(4)
# Out:
# Hello Python
# 안녕 파이썬
# 7
# 3.14
# [1, 2, 3]
# Hello---Python
# 1 2 3
# 1 2 3 4

# %% [markdown]
# #### [Lab] 구구단 출력
#
# * `print()` 함수를 사용하여 각 단마다 횡으로 출력

# %%
for i in range(2, 10):
  for j in range(1, 10):
    print("{0}X{1}={2}".format(i,j,i*j), end =' ')
  print('\n')
# Out:
# 2X1=2 2X2=4 2X3=6 2X4=8 2X5=10 2X6=12 2X7=14 2X8=16 2X9=18
#
# 3X1=3 3X2=6 3X3=9 3X4=12 3X5=15 3X6=18 3X7=21 3X8=24 3X9=27
#
# 4X1=4 4X2=8 4X3=12 4X4=16 4X5=20 4X6=24 4X7=28 4X8=32 4X9=36
#
# 5X1=5 5X2=10 5X3=15 5X4=20 5X5=25 5X6=30 5X7=35 5X8=40 5X9=45
#
# 6X1=6 6X2=12 6X3=18 6X4=24 6X5=30 6X6=36 6X7=42 6X8=48 6X9=54
#
# 7X1=7 7X2=14 7X3=21 7X4=28 7X5=35 7X6=42 7X7=49 7X8=56 7X9=63
#
# 8X1=8 8X2=16 8X3=24 8X4=32 8X5=40 8X6=48 8X7=56 8X8=64 8X9=72
#
# 9X1=9 9X2=18 9X3=27 9X4=36 9X5=45 9X6=54 9X7=63 9X8=72 9X9=81

# %% [markdown]
# ---

# %% [markdown]
# ## 파일 입출력(File Input/Output)

# %% [markdown]
# ### 파일 입출력 과정
#
# * 파일의 입출력 과정은 단계를 가짐
# * 파일을 열고, 파일을 읽거나 쓰고, 파일을 닫는 순서

# %% [markdown]
# ### 파일 열기/닫기
#
# * file.txt 파일을 생성하고, 열고 닫기

# %%
f = open("file.txt", 'w')
f = open('file.txt', 'r')
f.close()

# %%
# !ls file.txt
# Out:
# file.txt

# %% [markdown]
# ### 파일 모드(File Mode)

# %% [markdown]
# ### 텍스트 파일 쓰기

# %% [markdown]
# #### write()
#
# * `write()`를 이용하여 파일에 쓰기

# %%
f = open("file.txt" , "w")
f.write("Hello Python")
f.close()

# %%
# !cat file.txt
# Out:
# Hello Python

# %% [markdown]
# #### writelines()
#
# * `writelines()`를 이용하여 list를 파일에 쓰기

# %%
list = ["One\n", "Two\n", "Three\n"]
f = open("file.txt", 'w')
f.writelines(list)
f.close()

# %%
# !cat file.txt
# Out:
# One
# Two
# Three

# %% [markdown]
# #### 표준 입력 → 파일 쓰기
#
# * 표준 입력을 `input()` 함수를 통해 입력 받고, `write()` 함수를 통해 파일에 쓰기

# %%
text = input("입력: ")
f = open("file.txt", 'w')
f.write(text)
f.close()
# Out:
# 입력: 안녕하세요 박건우 입니다.

# %%
# !cat file.txt
# Out:
# 안녕하세요 박건우 입니다.

# %%
text = [str(text + '\n') for text in input("여러 값 입력: ").split()]
f = open("file.txt",'w')
f.writelines(text)
f.close()
# Out:
# 여러 값 입력: 1 2 3 4 5

# %%
# !cat file.txt
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
x = ""
text = ""
while x != 'q':
  x = input("반복 입력: ")
  text += x + '\n'
f = open("file.txt", 'w')
f.writelines(text)
f.close()
# Out:
# 반복 입력: 1
# 반복 입력:
# 반복 입력: 2
# 반복 입력: 3
# 반복 입력: 4
# 반복 입력: 5
# 반복 입력: q

# %%
# !cat file.txt
# Out:
# 1
#
# 2
# 3
# 4
# 5
# q

# %% [markdown]
# ### [Lab] 구구단 결과를 파일에 쓰기
#
# * 구구단 결과를 파일에 쓰기

# %%
f = open("dan.txt", 'w')
for i in range(2,10):
  for j in range(1,10):
    f.write("{0} X {1} = {2}\n".format(i,j,i*j))
  else:
    f.write("\n")
f.close()

# %%
# !cat dan.txt
# Out:
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
#
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27
#
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
#
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
#
# 6 X 1 = 6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
#
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
#
# 8 X 1 = 8
# 8 X 2 = 16
# 8 X 3 = 24
# 8 X 4 = 32
# 8 X 5 = 40
# 8 X 6 = 48
# 8 X 7 = 56
# 8 X 8 = 64
# 8 X 9 = 72
#
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81

# %% [markdown]
# ### 텍스트 파일 출력

# %% [markdown]
# * 텍스트 파일 예제

# %%
# !echo "동해물과 백두산이 마르고 닳도록" > anthem.txt
# !echo "하느님이 보우하사 우리나라 만세" >> anthem.txt

# %% [markdown]
# #### readline()
#
# * `readline()`를 이용하여 텍스트 파일을 라인 단위로 읽고 화면에 출력

# %%
f = open("anthem.txt", 'r')
while True:
  line = f.readline()
  if not line: break
  print(line)

f.close()
# Out:
# 동해물과 백두산이 마르고 닳도록
#
# 하느님이 보우하사 우리나라 만세

# %% [markdown]
# #### readlines()
#
# * `readlines()`를 이용하여 텍스트 파일의 여러 라인을 읽고 화면에 출력

# %%
f = open("anthem.txt", 'r')
lines = f.readlines()
print(lines)
f.close()
# Out:
# ['동해물과 백두산이 마르고 닳도록\n', '하느님이 보우하사 우리나라 만세\n']

# %% [markdown]
# #### read()
#
# * `read()`를 이용하여 텍스트 파일을 읽고 화면에 출력

# %%
f = open("anthem.txt", 'r')
data = f.read()
print(data)
f.close()
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세

# %% [markdown]
# #### tell()
#
# * 파일 포인터 위치 변경

# %%
f = open("anthem.txt", 'r')
while True:
  print(f.tell())
  line = f.readline()
  if not line: break
  print(line)

f.close()
# Out:
# 0
# 동해물과 백두산이 마르고 닳도록
#
# 46
# 하느님이 보우하사 우리나라 만세
#
# 92

# %% [markdown]
# #### seek()
#
# * 파일 포인터 위치 이동

# %%
f = open("anthem.txt", 'r')
f.seek(46)
line = f.readline()
print(line)
f.seek(0)
line = f.readline()
print(line)
f.close()
# Out:
# 하느님이 보우하사 우리나라 만세
#
# 동해물과 백두산이 마르고 닳도록

# %% [markdown]
# ### with 문
#
# * 항상 파일을 `open()` 함수로 열고, `close()` 함수로 닫아야 하는 일을 자동으로 처리
# * with문을 이용하면 with 블록 내에서 파일을 열고 벗어나면 파일을 닫음

# %%
f = open("file.txt", 'w')
f.write("Hello Python")
f.close()

# %%
with open("file.txt", 'w') as f:
  f.write("Hello Python")

# %% [markdown]
# ### [Lab] 표준 입력으로 받은 내용을 파일로 쓰기
#
# * 사용자로부터 표준 입력 받음
# * 받은 내용을 계속 파일 쓰기

# %%
f = open("file.txt",'w')
line = ""
while True:
  line = input()
  if not line: break
  f.writelines(line + '\n')

f.close()
# Out:
# 동해물과 백두산이
# 마르고 닳도록
# 하느님이 보우하사
# 우리나라 만세

# %%
# !cat file.txt
# Out:
# 동해물과 백두산이
# 마르고 닳도록
# 하느님이 보우하사
# 우리나라 만세

# %% [markdown]
# * 이진 파일(이미지) 예제

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-7d257303-a610-4659-b76d-660844fdf28e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7d257303-a610-4659-b76d-660844fdf28e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpg to cat.jpg
# {'cat.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00x\x00x\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x02\x01\x01\x02\x02\x02\x02\x02\x02\x02\x02\x03\x05\x03\x03\x03\x03\x03\x06\x04\x04\x03\x05\x07\x06\x07\x07\x07\x06\x07\x07\x08\t\x0b\t\x08\x08\n\x08\x07\x07\n\r\n\n\x0b\x0c\x0c\x0c\x0c\x07\t\x0e\x0f\r\x0c\x0e\x0b\x0c\x0c\x0c\xff\xdb\x00C|\x01\xb9\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x
xad\xc7\x8a/KI38\x1c\x15\xdcs\x8e\x95\xe2W:\xed\xce\xabvd\x96Y\x1c\xb1\xc9\xcbWo\xe0\xdbCu\x14m\xd7\xdd\xbb\n\xf4+aT5l\xf3i\xe2]Gs\xa0k\xa9%\x9c1$(8\x03\xae\x07\xaf\xd2\xb7\xbc=,\xad *\xcd\xe9\x8fju\x9e\x81\xf6\xb8\x01<\xb ...

# %%
# !ls
# Out:
# anthem.txt  cat.jpg  dan.txt  file.txt	sample_data

# %% [markdown]
# ### 이진 파일 복사
#
# * 하나의 이진 파일을 읽어서 다른 이진 파일로 쓰기 (복사)

# %%
input = open("cat.jpg", "rb")
output = open("cat_copy.jpg", 'wb')
while True:
  fp = input.read(1)
  if not fp: break
  output.write(fp)

input.close()
output.close()

# %%
# !ls
# Out:
# anthem.txt  cat_copy.jpg  cat.jpg  dan.txt  file.txt  sample_data

# %% [markdown]
# ## 디렉토리 및 파일 처리

# %% [markdown]
# ### 디렉토리 생성
#
# * 디렉토리와 파일을 다루는 다양한 함수를 제공하는 shutil와 os 라이브러리
# * `mkdir()`: 디렉토리 생성

# %%
import os
import shutil

os.mkdir("test3")
os.mkdir('test3/1')
os.mkdir('test3/2')
os.mkdir('test3/3')

# %%
# !ls
# Out:
#  anthem.txt	 cat.jpg    sample_data   'test'$'\002'   test2
#  cat_copy2.jpg	 dan.txt    test	  'test'$'\003'   test3
#  cat_copy.jpg	 file.txt  'test'$'\001'   test1

# %%
# !ls test3
# Out:
# 1  2  3

# %% [markdown]
# ### 디렉토리 및 파일 복사
#
# * `shutil.copy()`: 파일 복사
# * `shutil.copytree()`: 디렉토리 전체 복사

# %%
import shutil
shutil.copy("cat.jpg", "cat_copy2.jpg")
# Out:
# 'cat_copy2.jpg'

# %%
# !ls
# Out:
#  anthem.txt	 cat.jpg    sample_data   'test'$'\002'
#  cat_copy2.jpg	 dan.txt    test	  'test'$'\003'
#  cat_copy.jpg	 file.txt  'test'$'\001'   test1

# %%
import shutil
shutil.copytree("test1", "test2")
# Out:
# 'test2'

# %%
# !ls
# Out:
#  anthem.txt	 cat.jpg    sample_data   'test'$'\002'   test2
#  cat_copy2.jpg	 dan.txt    test	  'test'$'\003'
#  cat_copy.jpg	 file.txt  'test'$'\001'   test1

# %%
# !ls test2
# Out:
# 1  2  3

# %% [markdown]
# ### 디렉토리 및 파일 확인
#
# * `isdir()`: 디렉토리 존재 확인
# * `isfile()`: 파일 존재 확인
# * `exists()`: 디렉토리/파일 존재 확인

# %%
import os.path
print(os.path.isdir("test1"))
print(os.path.isdir("test1"))
print(os.path.isdir("test2"))
print(os.path.isfile("cat.jpg"))

print(os.path.isfile("cat_copy.jpg"))

print(os.path.exists("test1/1"))
print(os.path.exists("test2/2"))
print(os.path.isdir("test/4"))
# Out:
# True
# True
# True
# True
# True
# True
# True
# False

# %% [markdown]
# ### 디렉토리 목록 보기
#
# * `os.walk()`: 디렉토리 목록 보기

# %%
import os
for dir_name, dir_list, file_names in os.walk("./"):
  for file_name in file_names:
    print(os.path.join(dir_name, file_name))
# Out:
# ./dan.txt
# ./cat.jpg
# ./anthem.txt
# ./cat_copy2.jpg
# ./cat_copy.jpg
# ./file.txt
# ./.config/.last_survey_prompt.yaml
# ./.config/.last_update_check.json
# ./.config/active_config
# ./.config/config_sentinel
# ./.config/.last_opt_in_prompt.yaml
# ./.config/gce
# ./.config/.metricsUUID
# ./.config/configurations/config_default
# ./.config/logs/2020.07.30/16.29.44.119840.log
# ./.config/logs/2020.07.30/16.30.04.899171.log
# ./.config/logs/2020.07.30/16.29.49.434074.log
# ./.config/logs/2020.07.30/16.29.30.511119.log
# ./.config/logs/2020.07.30/16.30.04.254570.log
# ./.config/logs/2020.07.30/16.29.12.069758.log
# ./sample_data/README.md
# ./sample_data/anscombe.json
# ./sample_data/mnist_test.csv
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_test.csv
# ./sample_data/california_housing_train.csv

# %% [markdown]
# ### 디렉토리 및 파일 삭제
#
# * `os.remove()`: 파일 삭제
# * `shutil.rmtree()`: 디렉토리 안에 모든 파일/디렉토리 삭제

# %%
import os
os.remove("cat_copy2.jpg")

# %%
# !ls
# Out:
#  anthem.txt   dan.txt	 sample_data  'test'$'\001'  'test'$'\003'   test2
#  cat.jpg      file.txt	 test	      'test'$'\002'   test1	     test3

# %%
import shutil
shutil.rmtree('test1')
shutil.rmtree('test2')

# %%
# !ls
# Out:
#  anthem.txt   dan.txt	 sample_data  'test'$'\001'  'test'$'\003'
#  cat.jpg      file.txt	 test	      'test'$'\002'   test3

# %% [markdown]
# ### 파일 크기
#
# * `os.path.getsize()`: 파일의 크기를 바이트 단위로 출력

# %%
import os.path
print(os.path.getsize('cat.jpg'))
# Out:
# 71670

# %% [markdown]
# ### 파일 압축

# %%
import zipfile
comp = zipfile.ZipFile('new.zip', 'w')
comp.write('cat.jpg')
comp.close()

# %%
# !ls
# Out:
#  anthem.txt   dan.txt	 new	   sample_data	'test'$'\001'  'test'$'\003'
#  cat.jpg      file.txt	 new.zip   test		'test'$'\002'   test3

# %%
decomp = zipfile.ZipFile('new.zip','r')
decomp.extractall('new1')
decomp.close()

# %%
# !ls new1
# Out:
# cat.jpg
